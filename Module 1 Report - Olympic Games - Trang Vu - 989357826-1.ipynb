# %% [markdown]
# <p class="pull-left">
# ANLT 212 - Analytics Computing
# </p>
# <div class="pull-right">
# <ul class="list-inline">
# Copyright © Trang Vu 2019
# </ul>
# </div>

# %% [markdown]
# <font color='Navy' size=3><em> Trang Vu - 989357826<br>
# Module 1 Report Olympic Games</em>

# %% [markdown]
# <img src="https://seeklogo.net/wp-content/uploads/2011/05/kellogg-logo-vector-400x400.png" alt="Drawing" style="width: 350px" />

# %% [markdown]
# # <font color='Navy' size=10><center>MODULE 1 REPORT - <em>OLYMPIC GAMES </em></center></font>

# %% [markdown]
# ## <font color='black' size=6><ul class="list-inline">Objective of Proposed Research and Background Information</ul></font>

# %% [markdown]
# My objective through this Research is to utilize data exploration to gain comprehensive ideas about the data as well as
# the general percentage of some particular aspect like gender and season and the mean of value of some column to have
# a comprehensive picture of how and which direction and methodlogy I should utilize to retrieve and analyze data. I
# would select the age and weight colums to have a glance of their correlation then I will go deeper to the series part
# where I would use specific filtering and retrieving tools in R to define the correlation of different aspect in
# coherant with the Medal achievement.

# %% [markdown]
# Kellog's vission is: "Enrich & delight the world through foods and brands that matter". And its tagline is:"Let's make today great". Hence, through Kellog's vision and tagline, it is noticable to define the potential direction for target and segmentation of Kellogg's which targets on young people or millennials with high demand of energy and full nutritient breakfast and snacks for a busy working or studying day. Hence, in overall, I would like to pay my attention on these five typical columns for which I think could be helpful for Kellog's in term of finding the right athletes to sponsor. First of all, the "Name" column should be specified, name comes with reputation and imagination, which affects significantly the brandname. Secondly, age should be focused since fact has their own that "Age" is significantly affects the brand and its target segmentation; we also look into how well ages varies in term of Olympic history. Team and Year are also important since it define place and time, where we could find the frequencies and relevant of the informations. Finally, we should also concentrate on "Medal" column where represent the acomplishment and affection of a brandname.

# %% [markdown]
# In stead of focusing on all age group, I will pay more attention on young age group which represent youth and capabilityWhich is suitable with Kellog's brand and product lines. Kellog's product is lean into nutrient food for breakast with convienient and lively designs Which are suitable with young and potential athletes in order to deliver these messages. Hence,instead of selecting the old age group, I will pay more attention on the younger ones and evaluate their performance throughout the Olympic history. I will also focus on the most current 10 years for the validity and the current trend of the information which can help me predict the trend for the upcoming Olympic season. Especially, Kellog's has its headquarter in United States, China, Great Britian, Mexico and Ireland so my direction is to focus on these countries while conducting analyzation. We could predict the success of certain athletes based on their performance throughout history and countries where they came from.

# %% [markdown]
# ### <font color='dark grey' size=6><ul class="list-inline">1. Data Exploration </ul></font>

# %%
# Loading the data file using read.csv function and reading the data in the R environment.
athletes <- read.csv("athlete_events.csv",stringsAsFactors =F)

# %%
# Explore the first ten rows of the data
head(athletes,n=10)
# Out:
#    ID Name                     Sex Age Height Weight Team           NOC
# 1  1  A Dijiang                M   24  180    80     China          CHN
# 2  2  A Lamusi                 M   23  170    60     China          CHN
# 3  3  Gunnar Nielsen Aaby      M   24   NA    NA     Denmark        DEN
# 4  4  Edgar Lindenau Aabye     M   34   NA    NA     Denmark/Sweden DEN
# 5  5  Christine Jacoba Aaftink F   21  185    82     Netherlands    NED
# 6  5  Christine Jacoba Aaftink F   21  185    82     Netherlands    NED
# 7  5  Christine Jacoba Aaftink F   25  185    82     Netherlands    NED
# 8  5  Christine Jacoba Aaftink F   25  185    82     Netherlands    NED
# 9  5  Christine Jacoba Aaftink F   27  185    82     Netherlands    NED
# 10 5  Christine Jacoba Aaftink F   27  185    82     Netherlands    NED
#    Games       Year Season City        Sport
# 1  1992 Summer 1992 Summer Barcelona   Basketball
# 2  2012 Summer 2012 Summer London      Judo
# ...

# %%
# Explore the last ten rows of the data
tail(athletes,n=10)
# Out:
#        ID     Name                         Sex Age Height Weight Team
# 271107 135565 Fernando scar Zylberberg     M   27  168    76     Argentina
# 271108 135566 James Francis "Jim" Zylker   M   21  175    75     United States
# 271109 135567 Aleksandr Viktorovich Zyuzin M   24  183    72     Russia
# 271110 135567 Aleksandr Viktorovich Zyuzin M   28  183    72     Russia
# 271111 135568 Olga Igorevna Zyuzkova       F   33  171    69     Belarus
# 271112 135569 Andrzej ya                   M   29  179    89     Poland-1
# 271113 135570 Piotr ya                     M   27  176    59     Poland
# 271114 135570 Piotr ya                     M   27  176    59     Poland
# 271115 135571 Tomasz Ireneusz ya           M   30  185    96     Poland
# 271116 135571 Tomasz Ireneusz ya           M   34  185    96     Poland
#        NOC Games       Year Season City           Sport
# 271107 ARG 2004 Summer 2004 Summer Athina         Hockey
# ...

# %%
# Find out how many number of rows from the dataframe.
nrow(athletes)
# Out:
# [1] 271116

# %%
# Find out how many number of columns from the dataframe.
ncol(athletes)
# Out:
# [1] 15

# %%
# What are the names of each columns in the data table.
names(athletes)
# Out:
#  [1] "ID"     "Name"   "Sex"    "Age"    "Height" "Weight" "Team"   "NOC"
#  [9] "Games"  "Year"   "Season" "City"   "Sport"  "Event"  "Medal"

# %%
# Take a look at general information of each variables and the type of variables.
str(athletes)
# Out:
# 'data.frame':	271116 obs. of  15 variables:
#  $ ID    : int  1 2 3 4 5 5 5 5 5 5 ...
#  $ Name  : chr  "A Dijiang" "A Lamusi" "Gunnar Nielsen Aaby" "Edgar Lindenau Aabye" ...
#  $ Sex   : chr  "M" "M" "M" "M" ...
#  $ Age   : int  24 23 24 34 21 21 25 25 27 27 ...
#  $ Height: int  180 170 NA NA 185 185 185 185 185 185 ...
#  $ Weight: num  80 60 NA NA 82 82 82 82 82 82 ...
#  $ Team  : chr  "China" "China" "Denmark" "Denmark/Sweden" ...
#  $ NOC   : chr  "CHN" "CHN" "DEN" "DEN" ...
#  $ Games : chr  "1992 Summer" "2012 Summer" "1920 Summer" "1900 Summer" ...
#  $ Year  : int  1992 2012 1920 1900 1988 1988 1992 1992 1994 1994 ...
#  $ Season: chr  "Summer" "Summer" "Summer" "Summer" ...
#  $ City  : chr  "Barcelona" "London" "Antwerpen" "Paris" ...
#  $ Sport : chr  "Basketball" "Judo" "Football" "Tug-Of-War" ...
#  $ Event : chr  "Basketball Men's Basketball" "Judo Men's Extra-Lightweight" "Football Men's Football" "Tug-Of-War Men's Tug-Of-War" ...
# ...

# %% [markdown]
# ***Let's see which gender (female or male) has the most data of athletes.***

# %%
female.percent <- nrow(athletes[athletes$Sex == 'F',c("ID","Sex")])/nrow(athletes)

# %%
# Print a random first 5 rows of two columns containing city and gender which has female as a gender. 
head(athletes[athletes$Sex == "F",c("City","Sex")],n=5)
# Out:
#   City        Sex
# 5 Calgary     F
# 6 Calgary     F
# 7 Albertville F
# 8 Albertville F
# 9 Lillehammer F

# %%
#Calculate percentage of female genders in the data, assign the result to a variable
female.percent
# Out:
# [1] 0.2748713

# %%
#Calculate percentage of male genders in the data, assign the result to a variable
male.percent <- nrow(athletes[athletes$Sex == 'M',c("ID","Sex")])/nrow(athletes)

# %%
male.percent
# Out:
# [1] 0.7251287

# %% [markdown]
# ***Let's see which season (summer or winter) has the most data of athletes.***

# %%
#Calculate percentage of summer season in the data, assign the result to a variable
summer.percent <- nrow(athletes[athletes$Season == "Summer",c("ID","Season")])/nrow(athletes)

# %%
summer.percent
# Out:
# [1] 0.8208737

# %%
#Calculate percentage of winter season in the data, assign the result to a variable
winter.percent <- nrow(athletes[athletes$Season == "Winter",c("ID","Season")])/nrow(athletes)

# %%
winter.percent
# Out:
# [1] 0.1791263

# %%
#Assign records in Age column into age variable.
age <- athletes$Age

# %%
# Caculate mean and assign it into the variable.
age.mean <- mean(age, na.rm = TRUE)

# %%
# Print out the result. We have the average age of the athletes in the Olympic history.
age.mean
# Out:
# [1] 25.5569

# %% [markdown]
# This section is how I approach the data source and have a general ideas of this data, what it includes and the overall
# characteristic of the data, which provide me an overview of what it looks like and also gain some valuable information. It seems like male athletes participates the most in Olympic games whereare female has a more humble percentage. Most of Olympic games are held in the Summer Season while few occassions were in winter. The average age
# is 25-26 years old.

# %% [markdown]
# ### <font color="red" size=6><ul class="list-inline">2. One column selection</ul></font>

# %% [markdown]
# When it comes to select one column, I was hesitating to select either age or weight because they all interesting and
# urge me to wonder how young the athletes could be and which are the top highest weight to find out if there is any
# relevent among these top information. Since Kellog's is a food brand who target market is young customers with the healthy and enegry image, which urges me to wonder if the height and weight factors are important to consider those factors in term of represetatives for a brand. I decide to select and retrieve records for each ones; then comepare whatI have to solve my curiousity. Instead of focusing on the older age, I would think it is more reasonable to target on the younger ones in the most recent Olympic years which could provide more potential and comprehensive ideas of which favorable ages that Kellog should sponsor.

# %% [markdown]
# Let's take a look and select data from the highest weight athletes of the data sources

# %%
# Select Weight column and create a subset for top weight athletes with weight sorting orders. 
topweights <- athletes[order(athletes$Weight,decreasing = T),]

# %%
# Print out the top 10 highest weight from the Weight column only

# %%
head(topweights$Weight,n=10)
# Out:
#  [1] 214.0 214.0 198.0 190.0 182.0 182.0 180.0 178.0 176.5 176.5

# %%
# Print out top 10 records from the subset who have the most highest weight for the Weight column. 
head(topweights,n=10)
# Out:
#        ID     Name                          Sex Age Height Weight Team
# 23156   12177 Ricardo Blas, Jr.             M   21  183    214.0  Guam
# 23157   12177 Ricardo Blas, Jr.             M   25  183    214.0  Guam
# 205468 103159 Aytami Ruano Vega             M   27  200    198.0  Spain
# 75032   38075 Marek Galiski                 M   29  200    190.0  Poland
# 237040 118869 Christopher J. "Chris" Taylor M   22  196    182.0  United States
# 237041 118869 Christopher J. "Chris" Taylor M   22  196    182.0  United States
# 206353 103580 Valentyn Rusliakov            M   28  187    180.0  Ukraine
# 206005 103413 Leonel Wilfredo Ruz Carmona   M   29  187    178.0  Venezuela
# 94363   47755 Marcus Jerrold "Mark" Henry   M   21  190    176.5  United States
# 94364   47755 Marcus Jerrold "Mark" Henry   M   25  190    176.5  United States
#        NOC Games       Year Season City      Sport
# 23156  GUM 2008 Summer 2008 Summer Beijing   Judo
# ...

# %% [markdown]
# Let's select Age column and print the report with the 10 youngest age for athelets for that column

# %%
# Sort the order of records by age, create the subset of records with the sorting orders. 
findyoungest <- athletes[order(athletes$Age,decreasing=F),]

# %%
# Sort the order of records by age, create the subset only for Age column.
findyoungest2 <- athletes[order(athletes$Age,decreasing=F)[1:271116],]

# %%
# Let's take a look at the top 10 ranking of athletes in term of Age. 
head(unique(findyoungest2[c("Age")]),n=10)
# Out:
#        Age
# 142883 10
# 43469  11
# 9649   12
# 5225   13
# 518    14
# 266    15
# 205    16
# 88     17
# 27     18
# 168    19

# %%
# Create a subset for the top 10 youngest athelets in the most current years of Olympic 
#(start from 2006 until current)
topage <- findyoungest[findyoungest$Year >= 2006, ]

# %%
head(topage,10)
# Out:
#        ID     Name                           Sex Age Height Weight Team
# 85841   43528 Antoinette Joyce Guedia Mouafo F   12  170    55     Cameroon
# 49378   25434 Ana Iulia Dascl                F   13  183    60     Romania
# 55357   28392 Dwayne Benjamin Didon          M   13   NA    NA     Seychelles
# 126221  63643 Adzo Rebecca Kpossi            F   13  158    53     Togo
# 205724 103265 Yekaterina Olegovna Rudenko    F   13  180    69     Kazakhstan
# 221024 111044 Gaurika Singh                  F   13  155    45     Nepal
# 1422      799 Nafissatou Moussa Adamou       F   14  172    72     Niger
# 2613     1464 Ai Yanhan                      F   14  168    54     China
# 2614     1464 Ai Yanhan                      F   14  168    54     China
# 4877     2784 Fatim Alkrmova                 F   14  175    60     Azerbaijan
#        NOC Games       Year Season City           Sport
# 85841  CMR 2008 Summer 2008 Summer Beijing        Swimming
# ...

# %% [markdown]
# <br> Now, let's take a look at what we have here. I have selected the Weight column and retrieve the top ten records of athletes Who have the highest weight. It is significant to notice that among the top ten athletes with highest weight, they all have male as their gender. The top 10 are mostly in their 20s with the oldest being 29 and the latter being 21. Interestingly, athlete named Ricardo Blas, Jr.has the highest weight at the most young age in the list (21 years old), from Guam team; followed by another team member also from Guam.It is noticable to conclude that wrestling has the most highest weight athletes, followed by judo and weightlifting sport type. United states has the most highest weight athletes among top 10, which could help to indicates that these type of sports are favorable in this country. There are significant relevant between height and weight where high weight athletes also have their height being high.
# When it comes to Age column selection, it is considerable to notice that the top 10 youngest ages are supprisingly young. The top youngest age is 10, followed by 11. In the most current year of Olympic, the youngest age are 12 and most of them are female. The typical sport for this age is Swimming. The popular Olympic season that they attends is Summer and Rio de Janeiro is the popular city where the most young female athletes come from here.<br><br>

# %% [markdown]
# ### <font color='red' size=6><ul class="list-inline">3. Series </ul></font>

# %% [markdown]
# Before selecting five different columns of my choice. Let's take a look at Kellog's vision and tagline. Kellog's vission is: "Enrich & delight the world through foods and brands that matter". And its tagline is:"Let's make today great". Hence, through Kellog's vision and tagline, it is noticable to define the potential direction for target and segmentation of Kellogg's which targets on young people or millennials with high demand of energy and full nutritient breakfast and snacks for a busy working or studying day. Hence, in overall, I would like to pay my attention on these five typical columns for which I think could be helpful for Kellog's in term of finding the right athletes to sponsor. First of all, the "Name" column should be specified, name comes with reputation and imagination, which affects significantly the brandname. Secondly, age should be focused since fact has their own that "Age" is significantly affects the brand and its target segmentation; we also look into how well ages varies in term of Olympic history. Team and Year are also important since it define place and time, where we could find the frequencies and relevant of the informations. Finally, we should also concentrate on "Medal" column where represent the acomplishment and affection of a brandname.

# %%
#Filter and select five defined columns.
series <- athletes[,c("Name","Age","Team","Year","Medal")]

# %%
#Take a quick glance of the subset
head(series,n=5)
# Out:
#   Name                     Age Team           Year Medal
# 1 A Dijiang                24  China          1992 NA
# 2 A Lamusi                 23  China          2012 NA
# 3 Gunnar Nielsen Aaby      24  Denmark        1920 NA
# 4 Edgar Lindenau Aabye     34  Denmark/Sweden 1900 Gold
# 5 Christine Jacoba Aaftink 21  Netherlands    1988 NA

# %%
#Let's exclude the NA Medal and take a quick glance at what we have here.
series_rm_na <- series[!is.na(series$Medal),]

# %%
head(series_rm_na,n=5)
# Out:
#    Name                     Age Team           Year Medal
# 4  Edgar Lindenau Aabye     34  Denmark/Sweden 1900 Gold
# 38 Arvo Ossian Aaltonen     30  Finland        1920 Bronze
# 39 Arvo Ossian Aaltonen     30  Finland        1920 Bronze
# 41 Juhamatti Tapio Aaltonen 28  Finland        2014 Bronze
# 42 Paavo Johannes Aaltonen  28  Finland        1948 Bronze

# %%
#Let's find the frequencies of Gold and Bronze medal in accordance to age, then review the top 10 among athletes that
#has the most frequencies.
# Add one more column in the subset to count the frequency of the Medal.
series_rm_na$Medalcount<- 0

# %%
#Assign value 1 to column Medalcount if the athletes has medal of gold or bronze. 
series_rm_na$Medalcount[series_rm_na$Medal=='Gold'] <- 1

# %%
series_rm_na$Medalcount[series_rm_na$Medal=='Silver'] <- 1

# %%
tail(series_rm_na,n=5)
# Out:
#        Name                                Age Team         Year Medal
# 271079 Galina Ivanovna Zybina (-Fyodorova) 25  Soviet Union 1956 Silver
# 271081 Galina Ivanovna Zybina (-Fyodorova) 33  Soviet Union 1964 Bronze
# 271083 Bogusaw Zych                        28  Poland       1980 Bronze
# 271103 Olesya Nikolayevna Zykina           19  Russia       2000 Bronze
# 271104 Olesya Nikolayevna Zykina           23  Russia       2004 Silver
#        Medalcount
# 271079 1
# 271081 0
# 271083 0
# 271103 0
# 271104 1

# %%
series_rm_na1 <- series_rm_na[series_rm_na$Medalcount == 1,]

# %%
# Since we target on young athletes and from the first section, I was caclulating the mean of age.
# The mean of age is around 25. Let's pick this age to set the limit in our subset and find out the frequency of 
# of athletes who is 25 or younger get the medal. 
age <-series_rm_na1[series_rm_na1$Age <= 25,]

# %%
age_fr <- table(age$Age,age$Medalcount)

# %%
age_fr
# Out:
#
#         1
#   11    1
#   12    3
#   13   14
#   14   57
#   15  142
#   16  245
#   17  362
#   18  574
#   19  900
#   20 1312
#   21 1785
#   22 2078
#   23 2279
#   24 2183
#   25 2079

# %% [markdown]
# Let's see which age has the most frequencies of participating Olympic Games and gaining Medal.

# %%
getmode <- function(v) {
   uniqv <- unique(v)
   uniqv[which.max(tabulate(match(v, uniqv)))]
}

# %%
agemost <-getmode(series_rm_na1$Age)

# %%
agemost
# Out:
# [1] 23

# %%
Let's see which teams has the most frequencies of participating Olympic Games and gaining Medal.
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:4: unexpected INCOMPLETE_STRING
# 1: Let's see which teams has the most frequencies of participating Olympic Games and gaining Medal.
#        ^
# Traceback:

# %%
getmode <- function(v) {
   uniqv <- unique(v)
   uniqv[which.max(tabulate(match(v, uniqv)))]
}

# %%
citymost <- getmode(series_rm_na1$Team)

# %%
citymost
# Out:
# [1] "United States"

# %% [markdown]
# Since Kellog's products are popular and sold all over different countries. Let's focus on the headquarter area where
# the representives could participate with Kellog in different campains.
# I would like to filter and pick these cities only for analyzing: United States, Great Britian, Ireland, China, and Mexico. Let see their frequency of getting medal.

# %%
city <-series_rm_na1[series_rm_na1$Team == "United States",]

# %%
city_fr <- table(city$Team,city$Medalcount)

# %%
# Frequencies of gaining medals from US athletes.
city_fr
# Out:
#
#                    1
#   United States 3986

# %%
city2 <-series_rm_na1[series_rm_na1$Team == "Great Britain",]

# %%
city2_fr <- table(city2$Team,city2$Medalcount)

# %%
# Frequencies of gaining medals from Great Britian athletes.
city2_fr
# Out:
#
#                    1
#   Great Britain 1101

# %%
city3 <-series_rm_na1[series_rm_na1$Team == "Ireland",]

# %%
city3_fr <- table(city3$Team,city3$Medalcount)

# %%
# Frequencies of gaining medals from Ireland athletes.
city3_fr
# Out:
#
#            1
#   Ireland 22

# %%
city4 <-series_rm_na1[series_rm_na1$Team == "China",]

# %%
city4_fr <- table(city4$Team,city4$Medalcount)

# %%
# Frequencies of gaining medals from China athletes.
city4_fr
# Out:
#
#           1
#   China 633

# %%
city5 <-series_rm_na1[series_rm_na1$Team == "Mexico",]

# %%
city5_fr <- table(city5$Team,city5$Medalcount)

# %%
# Frequencies of gaining medals from Mexico athletes.
city5_fr
# Out:
#
#           1
#   Mexico 56

# %% [markdown]
# So far, we see that young people in their age of 23 comes from United state are high target at the moment.

# %%
year0 <-series_rm_na1[series_rm_na1$Year >= 2006,]

# %%
year0_fr <- table(year0$Year,year0$Medalcount)

# %%
year0_fr
# Out:
#
#           1
#   2006  351
#   2008 1338
#   2010  349
#   2012 1262
#   2014  399
#   2016 1320

# %% [markdown]
# 2008 year until now, athletes has a lot of medal when it comes to the frequence in the latest 10 year.

# %%
getmode <- function(v) {
   uniqv <- unique(v)
   uniqv[which.max(tabulate(match(v, uniqv)))]
}

# %%
result <- getmode(series_rm_na1$Year)

# %%
result
# Out:
# [1] 2008

# %% [markdown]
# Let's filter everything and find out who is our target athletes for Kellog's to sponsor.

# %%
all <- series_rm_na1[series_rm_na1$Year == 2008 & series_rm_na1$Team == "United States" & series_rm_na1$Age == 23,]

# %%
all_fr <- table(all$Name,all$Medalcount)

# %%
nrow(all_fr)
# Out:
# [1] 20

# %%
all_fr
# Out:
#
#                                            1
#   Alison Gregorka                          1
#   Benjamin Marshall "Ben" Wildman-Tobriner 1
#   Brittany Hayes                           1
#   Caitlin Lowe                             1
#   Christopher Emmanuel "Chris" Paul        1
#   Elsie Windes                             1
#   Garrett Weber-Gale                       2
#   Heather Ann OReilly (-Werry)             1
#   Kimberly Marie "Kim" Glass               1
#   LeBron Raymone James                     1
#   Mariel Leigh Zagunis                     1
#   Matthew "Matt" Grevers                   3
#   Michael "Mike" Day                       1
#   Michael Fred Phelps, II                  8
#   Monica Cecilia Abbott                    1
#   Patricia "Patty" Cardenas                1
#   Peter Dale Varellas                      1
#   Reginald Edwin "Regi" Witherspoon        1
#   Sanya Richards-Ross                      1
#   Timothy Julien "Tim" Hutten              1

# %% [markdown]
# We could see in here that Michael Fred Phelps satisfy all the filtering requirement.
# Let's find out Michael Fred Phelps performance in the whole olympic history

# %%
michael <- series_rm_na1[series_rm_na1$Name == "Michael Fred Phelps, II",]

# %%
michael_fr<- table(michael$Name,michael$Medalcount)

# %%
michael_fr
# Out:
#
#                            1
#   Michael Fred Phelps, II 26

# %%
# Using getmode function to find out whether Michael Fred Phelps are the athletes who has the highest performance
#throughout Olympic year.
namemost <- getmode(series_rm_na$Name)

# %%
namemost
# Out:
# [1] "Michael Fred Phelps, II"

# %% [markdown]
# After a series of analysis. It is significant to recognize the pattern and the element that we are working
# on. Young athletes at their age of 20-24 come from United States and Great Britian having high performance and
# acomplishment in the lastest ten year of Olympic games. One of the potential name that stand out the most in the list
# are Michael Fred Phelps, II with 26 golds and silvers through out the Olympic history.

# %% [markdown]
# ### <font color='red' size=6><ul class="list-inline">4. Plot Design and Explaination </ul></font>

# %% [markdown]
# We have about 73 percent Male Olympic atheletes and 27 percent Female Olympic atheletes.<br>
# Let take a look this pie chart!

# %%
slices <- c(female.percent,male.percent)
lbls <- c("Female","Male")
pie(slices,labels = lbls, main = " Gender Pie Chart of Olympic atheletes ")
# Out:
# Plot with title “ Gender Pie Chart of Olympic atheletes ”

# %% [markdown]
# We have about 80 percent Summer Season Olympic atheletes and 18 percent Winter Season Olympic atheletes.<br>
# Let take a look this pie chart!

# %%
slices <- c(summer.percent,winter.percent)
lbls2 <- c("Summer","Winter")
pie(slices,labels = lbls2, main = "Season Pie Chart of Olympic history")
# Out:
# Plot with title “Season Pie Chart of Olympic history”

# %%
library(ggplot2)

# %% [markdown]
# Lets see the relationship between age and medal.

# %%
Age <- series_rm_na$Age

# %%
# Use the subset that we create in the last section.
#series_rm_na is the subset excluding all the NA value in the Medal column.
plot (Age ,main = "Age group and Medal", col = "blue")
# Out:
# Plot with title “Age group and Medal”

# %% [markdown]
# We could see in here the age group being from 20 to 30 has high frequencies of gaining Medal.

# %% [markdown]
# Let's see how different team in our targeted five countried varies in term of Medal gaining frequencies.

# %%
# Use the subset created from the last section for each cities US (city), Great Britian (city2), Ireland (city3)
#China (city4), Mexico(city5) to caclulae the sum of the frequencies and to define the ratio. 
city_total_fr<- city_fr[1] + city2_fr[1] + city3_fr[1] + city4_fr[1] + city5_fr[1]

# %%
city_total_fr
# Out:
# [1] 5798

# %%
us_percent <- city_fr[1]/city_total_fr

# %%
us_percent
# Out:
# [1] 0.6874784

# %%
brit_percent <- city2_fr[1]/city_total_fr

# %%
brit_percent
# Out:
# [1] 0.1898931

# %%
ire_percent <- city3_fr[1]/city_total_fr

# %%
ire_percent
# Out:
# [1] 0.003794412

# %%
chin_percent <- city4_fr[1]/city_total_fr

# %%
chin_percent
# Out:
# [1] 0.1091756

# %%
mex_percent <- city5_fr[1]/city_total_fr

# %%
mex_percent
# Out:
# [1] 0.009658503

# %%
slices1 <- c(us_percent,brit_percent,ire_percent,chin_percent,mex_percent)

# %%
lblsteam <- c("US 70%","Great Britian 19%","Ireland 0.3 %","China 10% ","Mexico 1.5 %")

# %%
pie(slices1,labels = lblsteam, main = "Top 5 Teams Pie Chart of Olympic history")
# Out:
# Plot with title “Top 5 Teams Pie Chart of Olympic history”

# %% [markdown]
# United State occupied more than half of the pie chart, followed by Great Britian and China. Whereas, Ireland and Mexico occupies very insignificant ratio.

# %%
Year <- as.numeric(year0$Year)

# %%
plot (Year ,main = "Olympic year and Medal", col = "blue")
# Out:
# Plot with title “Olympic year and Medal”

# %%
# Let's use ggplot to see the relationship between Age and Olympic Year through out the History
# to find out the relevant and which years has the most young atheltes. In this execirse, I would like to use the
# series_rm_na as data that I created from the last section which exclude the NA in the medal and only count 
# values in Medal column. 
olympic_plot <- ggplot(data = series_rm_na, 
                       mapping = aes(x = Age, y = Year))

# %%
olympic_plot + geom_point(alpha = 0.1, color = "red")
# Out:
# Warning message:
# “Removed 732 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# In overall, it is significant ot notice that there are strong corelation among age group, year of Olympic,Team, and
# the reputation of the person. From the plot chart above, it is undeniable that age group varies per years but it is
# noticable that there are high volume of young people participating in Olympic in the lastest 10 year in comparision with those participated in the past. There are decrease in term of older people ranging from 40 to 60 when it comes to the most recent years. This chart help me to define the frequency of data as well the trending to see if there is a relevant among these two group and Kellog's could base on this to define the year which has significant young athletes or in target age for the sponsor campaign.

# %% [markdown]
# ### <font color='red' size=6><ul class="list-inline">5. Summary Of The Report After Conducting Analysis</ul></font>

# %% [markdown]
# To sum up, I would like to conclude my Module 1 report with four differen aspects. It seems like male athletes
# participates the most in Olympic games whereare female has a more humble percentage. Most of Olympic games are held
# in the Summer Season while few occassions were in winter. The average age is 25-26 years old.
# It is noticable to conclude that wrestling has the most highest weight athletes, followed by judo and weightlifting
# sport type. United states has the most highest weight athletes among top 10, which could help to indicates that these
# type of sports are favorable in this country. There are significant relevant between height and weight where high
# weight athletes also have their height being high.This is also what Kellog's could consider when target customers
# in the food products focusing on healthy nutritient and enegry.When it comes to Age column selection, it is
# considerable to notice that the top 10 youngest ages are supprisingly young. The top youngest age is 10, followed by 11 and 12.
# In the most current year of Olympic, the youngest age are 12 and most of them are female.What we conducted in this reports are the top potential atheletes in the most current year who win medal and have great performance are from the age range of 20-25 with 23 is the most potential age. Thirdly, 70% athletes that win medal in the most recent years are from US, followed by Great Britian with 19% and Chinaa with 10% while Mexico and Ireland only occupies for 1% and 0.3% respectively. USA has significant for Olympic throughout the history. After a series of analysis. It is significant to recognize the pattern and the element that we are working on. Young athletes at their age of 20-24 come from United States and Great Britian having high performance and acomplishment in the lastest ten year of Olympic games. One of the potential name that stand out the most in the list are Michael Fred Phelps, II with 26 golds and silvers through out the Olympic history with the sport type of swimming.

# %% [markdown]
# <image src="https://dlpng.com/png/5296240" style="width: 350px" />

# %% [markdown]
# ### <font color='red' size=6><ul class="list-inline">6. Recommendation To Kellogg's Executives </ul></font>

# %% [markdown]
#
#  When it comes to recommendation to Kellog's Executives, I would like to demonstrate the fact thet Kellog's should look into long and short term plans to make sure they go align with the sponsor atheletes that they want to target on. United States is never-ending strong market at the moment since their headquarter and manufacter is here and they have large amount of consumers. According to my report, large propotation of young United State athletes participate in Olympic and gain Medals, which indicates the fact that sport is one of the strong factor and favorable in United States and there will be large amount of young adults particiate in Olympic in the upcoming years. The recommended age of athletes that Kellog's should sponsor is 23 years old which are showned in the report as the most popular and potential ages of the athlete to participate in Olympic Games and win medal. The age and the performance as well as the reputation of the athletes affect significantly the the imagination of the brand. Kellogg's should pick the athlete who can show off their youth energy and active performance, which go align with Kellogg's vision and mission to deliver nutrient breakfast and snack and providing nutrient and energy for whole day long. Michael Fred Phelps, II is a potential athletes who nonstop win uncountable achievements throughtout Olympic years and based on his frequencies, he has high potential of winning the next Olympic game in 2020. Kellogg's should consider sponsor and choose him as a representative for the brand. Beside, stay concetrating on the age group and choose United States is a local strong market to boost sale with sponsoring Olympic. However, Kellogg's could also consider Great Britian and China where also have high potential frequencies of ahtletes winning Medal in the latest 10 years. If Kellog's think about expand market and boost sales in the concurrent foreign market where it has headquarters there then Great Britian is the second great option, followed by China since Kellogg's product lines are more popular to Western market than the Asian ones. The reason to choose the country that have Kellogg's headquarter since it could provide Kellogg's more opportunity to promote and boost imagination through different campaings witht the sponsored athletes.

# %% [markdown]
# <img src="https://seeklogo.net/wp-content/uploads/2018/01/tokyo-2020-olympic-logo.png" alt="Free download Tokyo 2020 Olympic logo vector" alt="Drawing" style="width: 300px;"/>
